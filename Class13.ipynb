# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/IntelligentCommunication/blob/main/Class13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Integrating Interfaces with Back-ends**
# Effective chatbot performance hinges on the seamless bidirectional communication between a front-end interface and a back-end processor, typically facilitated by structured APIs. While frameworks like PyQt5 or React enable the creation of these visual touchpoints, the quality of the user experience depends on more than just basic connectivity; it requires dynamic elements like buttons and menus to guide interactions and technical optimizations like "lazy loading" and caching to ensure responsiveness. Ultimately, a successful integration demands a rigorous cycle of automated testing with tools like Selenium and performance tuning to prevent latency, resulting in an intuitive and reliable system for the end user.

# %%
# Importing all the necessary libraries and resources:
import sys
import google.generativeai as genai

# Installing PyQt5:
# !pip install PyQt5

from PyQt5.QtWidgets import QApplication, QMainWindow, QTextEdit, QLineEdit, QPushButton, QVBoxLayout, QWidget
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 51.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 14.9 MB/s eta 0:00:00
# ...

# %%
# Configuring the API Key on Google AI:
genai.configure(api_key='AIzaSyBj1-A7It86V1raUZoVLEIIwa9DVHoRVRo')

# Initializing the Generative AI model:
model = genai.GenerativeModel('gemini-1.5-pro-latest')
chat = model.start_chat(history=[])
