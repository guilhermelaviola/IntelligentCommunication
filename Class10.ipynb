# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/IntelligentCommunication/blob/main/Class10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **API Fundamentals**
# RESTful APIs serve as the backbone of modern software interoperability, enabling different applications to exchange data efficiently through standardized HTTP protocols. By leveraging core principles like statelessness, cacheability, and CRUD operations (Create, Read, Update, Delete), these APIs provide a scalable and predictable framework for resource management. Success in API development hinges on clear documentation of endpoints, the strategic choice of languages and frameworks, and the implementation of robust security measures like OAuth or JWT. Ultimately, a well-architected RESTful API—whether internal or external like the Google Gemini API—facilitates seamless integration and enhances application capabilities in an increasingly interconnected digital ecosystem.

# %%
# !pip install PyQt5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 12.3 MB/s eta 0:00:00
# ...

# %%
# Importing all the necessary libraries and resources:
import sys
import google.generativeai as genai
from PyQt5.QtWidgets import (QApplication, QMainWindow, QTextEdit, QLineEdit, QPushButton, QVBoxLayout, QWidget)

# %% [markdown]
# ## **Example: AI Chatbot application**
# The following example implements a desktop-based AI Chatbot application using Python. It bridges a modern Large Language Model (LLM) with a classic graphical user interface (GUI) using Google Generative AI, PyQt5 Framework and Request-Response Loop logic.

# %%
# Configuring the Google AI API Key:
genai.configure(api_key='AIzaSyBj1-A7It86V1raUZoVLEIIwa9DVHoRVRo')

# %%
# Initializing the Generative AI model:
model = genai.GenerativeModel('gemini-1.5-pro-latest')
chat = model.start_chat(history=[])

# %%
# Defining the user interface using PyQt5:
class ChatbotApp(QMainWindow):
  def __init__(self):
    super().__init__()

    self.setWindowTitle('Chatbot with Google AI')
    self.setGeometry(100, 100, 500, 400)

    # Interface layout:
    layout = QVBoxLayout()

    # Textbox to display the chat:
    self.chat_box = QTextEdit(self)
    self.chat_box.setReadOnly(True)
    layout.addWidget(self.chat_box)

    # Text input for user question:
    self.input_box = QLineEdit(self)
    layout.addWidget(self.input_box)

    # Send button:
    self.send_button = QPushButton('Send', self)
    self.send_button.clicked.connect(self.send_question)
    layout.addWidget(self.send_button)

    # Widget central for the layout:
    container = QWidget()
    container.setLayout(layout)
    self.setCentralWidget(container)

# Function to send the question:
def send_question(self):
    user_question = self.input_box.text()
    if user_question.lower() == 'end':
      self.close()
    else:
      # Sending the question to the Google AI model:
      response = chat.send_message(user_question)
      text_response = response.text  # Getting the model response

      # Displaying the question and answer on the interface:
      self.chat_box.append('You: ' + user_question)
      self.chat_box.append('Chatbot: ' + text_response)

      # Cleaning the input field:
      self.input_box.clear()

# Main function to run the app:
def main():
    app = QApplication(sys.argv)
    chatbot = ChatbotApp()
    chatbot.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()
